# %% [markdown]
# #### 0.思路说明如下：
# 1）把需要调整的参数制作为栅格（grid search，暂时作此翻译）；
# 2）用R语言中的for循环依次调用栅格中的每一组参数训练模型，记录模型在model中，记录评估结果在perf中，然后删除对应模型，以免内存溢出；
# 3）选择损失函数（loss function）最小的，即为最优模型；可以使用此模型的参数代入全部训练数据进行训练。

# %% [markdown]
# #### 1.加载测试程序需要的包

# %%
library(lightgbm)
# Out:
# Loading required package: R6

# %% [markdown]
# #### 2.加载测试数据（ lightgbm自带案例数据，请根据实际情况选择路径）

# %%
train <- read.table(file = 'C:/Users/Administrator/LightGBM/examples/multiclass_classification/multiclass.train') 
test <- read.table(file = 'C:/Users/Administrator/LightGBM/examples/multiclass_classification/multiclass.test')

# %%
dtrain <- lgb.Dataset(data.matrix(train[, 2:29]), label = train$V1, free_raw_data = FALSE)
dtest <- lgb.Dataset.create.valid(dataset = dtrain, data = data.matrix(test[, 2:29]), label = test$V1)
valids <- list(test = dtest)

# %% [markdown]
# #### 3.构建搜索栅格（也可以设置为随机搜索）

# %%
grid_search <- expand.grid(
    Learning_rate = seq(from = 0.1, to = 1, by = .1),
    Num_leaves = seq(from = 5, to = 50, by = 5)
)

# %% [markdown]
# #### 4.将建立的每一个模型放在model(一个list),交叉验证的评估放在perf中

# %%
perf <- numeric(nrow(grid_search))

# %% [markdown]
# #### 5.通过循环运行lightgbm（解决循环次数较多时会致使内存溢出的问题！）

# %%
for (i in 1:nrow(grid_search)) {
  model <- lgb.train(
    list(
      objective = "multiclass",
      metric = "multi_logloss",
      num_class = 5,
      #lambda_l1 = grid_search[i, "L1"],
      #lambda_l2 = grid_search[i, "L2"],
      learning_rate = grid_search[i, 'Learning_rate'],
      num_leaves = grid_search[i, 'Num_leaves']
    ),
    data = dtrain,
    nrounds = 10,
    valids = valids,
    early_stopping_rounds = 10,
    num_iterations = 100
  )
  perf[i] <- mean(unlist(model$record_evals$test$multi_logloss$eval))
  rm(model)
  gc() ## 清理R内存，此函数可不用，因为R在需要内存时会自动清理已经删除的文件（实际测试，偶尔不灵）
}
# Out:
# [1]:	test's multi_logloss:1.60654
# [2]:	test's multi_logloss:1.60331
# [3]:	test's multi_logloss:1.59858
# [4]:	test's multi_logloss:1.59524
# [5]:	test's multi_logloss:1.59264
# [6]:	test's multi_logloss:1.5897
# [7]:	test's multi_logloss:1.58666
# [8]:	test's multi_logloss:1.58356
# [9]:	test's multi_logloss:1.58114
# [10]:	test's multi_logloss:1.57751
# [1]:	test's multi_logloss:1.60398
# [2]:	test's multi_logloss:1.59552
# [3]:	test's multi_logloss:1.59224
# [4]:	test's multi_logloss:1.58658
# [5]:	test's multi_logloss:1.58019
# [6]:	test's multi_logloss:1.57503
# [7]:	test's multi_logloss:1.56855
# [8]:	test's multi_logloss:1.56191
# [9]:	test's multi_logloss:1.55838
# [10]:	test's multi_logloss:1.55316
# [1]:	test's multi_logloss:1.60175
# [2]:	test's multi_logloss:1.58929
# [3]:	test's multi_logloss:1.58078
# [4]:	test's multi_logloss:1.57315
# [5]:	test's multi_logloss:1.56593
# [6]:	test's multi_logloss:1.55781
# [7]:	test's multi_logloss:1.54811
# [8]:	test's multi_logloss:1.53976
# [9]:	test's multi_logloss:1.5308
# [10]:	test's multi_logloss:1.52045
# [1]:	test's multi_logloss:1.59987
# [2]:	test's multi_logloss:1.58857
# [3]:	test's multi_logloss:1.58157
# [4]:	test's multi_logloss:1.56631
# [5]:	test's multi_logloss:1.55633
# [6]:	test's multi_logloss:1.54442
# [7]:	test's multi_logloss:1.53506
# [8]:	test's multi_logloss:1.52548
# [9]:	test's multi_logloss:1.51489
# [10]:	test's multi_logloss:1.50689
# [1]:	test's multi_logloss:1.59834
# [2]:	test's multi_logloss:1.589
# [3]:	test's multi_logloss:1.57907
# [4]:	test's multi_logloss:1.56042
# [5]:	test's multi_logloss:1.54577
# [6]:	test's multi_logloss:1.53373
# [7]:	test's multi_logloss:1.52565
# [8]:	test's multi_logloss:1.51266
# [9]:	test's multi_logloss:1.50144
# [10]:	test's multi_logloss:1.48539
# [1]:	test's multi_logloss:1.59716
# [2]:	test's multi_logloss:1.58649
# [3]:	test's multi_logloss:1.57583
# [4]:	test's multi_logloss:1.55728
# [5]:	test's multi_logloss:1.53924
# [6]:	test's multi_logloss:1.52955
# [7]:	test's multi_logloss:1.50723
# [8]:	test's multi_logloss:1.49658
# [9]:	test's multi_logloss:1.48353
# [10]:	test's multi_logloss:1.4705
# [1]:	test's multi_logloss:1.59633
# [2]:	test's multi_logloss:1.58385
# [3]:	test's multi_logloss:1.57366
# [4]:	test's multi_logloss:1.55607
# [5]:	test's multi_logloss:1.53256
# [6]:	test's multi_logloss:1.51447
# [7]:	test's multi_logloss:1.49868
# [8]:	test's multi_logloss:1.48505
# [9]:	test's multi_logloss:1.47282
# [10]:	test's multi_logloss:1.46054
# [1]:	test's multi_logloss:1.59587
# [2]:	test's multi_logloss:1.58257
# [3]:	test's multi_logloss:1.57461
# [4]:	test's multi_logloss:1.54679
# [5]:	test's multi_logloss:1.53337
# [6]:	test's multi_logloss:1.52302
# [7]:	test's multi_logloss:1.49758
# [8]:	test's multi_logloss:1.48453
# [9]:	test's multi_logloss:1.46881
# [10]:	test's multi_logloss:1.45649
# [1]:	test's multi_logloss:1.59576
# [2]:	test's multi_logloss:1.58191
# [3]:	test's multi_logloss:1.57128
# [4]:	test's multi_logloss:1.5412
# [5]:	test's multi_logloss:1.52464
# [6]:	test's multi_logloss:1.50667
# [7]:	test's multi_logloss:1.4844
# [8]:	test's multi_logloss:1.46745
# [9]:	test's multi_logloss:1.4538
# [10]:	test's multi_logloss:1.4375
# [1]:	test's multi_logloss:1.59602
# [2]:	test's multi_logloss:1.58102
# [3]:	test's multi_logloss:1.55444
# [4]:	test's multi_logloss:1.54023
# [5]:	test's multi_logloss:1.52696
# [6]:	test's multi_logloss:1.49519
# [7]:	test's multi_logloss:1.46553
# [8]:	test's multi_logloss:1.44244
# [9]:	test's multi_logloss:1.43604
# [10]:	test's multi_logloss:1.42621
# [1]:	test's multi_logloss:1.60233
# [2]:	test's multi_logloss:1.59744
# [3]:	test's multi_logloss:1.5911
# [4]:	test's multi_logloss:1.58602
# [5]:	test's multi_logloss:1.58138
# [6]:	test's multi_logloss:1.57578
# [7]:	test's multi_logloss:1.56939
# [8]:	test's multi_logloss:1.56469
# [9]:	test's multi_logloss:1.55917
# [10]:	test's multi_logloss:1.55299
# [1]:	test's multi_logloss:1.59586
# [2]:	test's multi_logloss:1.58518
# [3]:	test's multi_logloss:1.57509
# [4]:	test's multi_logloss:1.56374
# [5]:	test's multi_logloss:1.55138
# [6]:	test's multi_logloss:1.54347
# [7]:	test's multi_logloss:1.53512
# [8]:	test's multi_logloss:1.53059
# [9]:	test's multi_logloss:1.52107
# [10]:	test's multi_logloss:1.51317
# [1]:	test's multi_logloss:1.59006
# [2]:	test's multi_logloss:1.57611
# [3]:	test's multi_logloss:1.56025
# [4]:	test's multi_logloss:1.54632
# [5]:	test's multi_logloss:1.53054
# [6]:	test's multi_logloss:1.51669
# [7]:	test's multi_logloss:1.50277
# [8]:	test's multi_logloss:1.48878
# [9]:	test's multi_logloss:1.47611
# [10]:	test's multi_logloss:1.46672
# [1]:	test's multi_logloss:1.58493
# [2]:	test's multi_logloss:1.56632
# [3]:	test's multi_logloss:1.55364
# [4]:	test's multi_logloss:1.53732
# [5]:	test's multi_logloss:1.51705
# [6]:	test's multi_logloss:1.49961
# [7]:	test's multi_logloss:1.48685
# [8]:	test's multi_logloss:1.47317
# [9]:	test's multi_logloss:1.4565
# [10]:	test's multi_logloss:1.44596
# [1]:	test's multi_logloss:1.58047
# [2]:	test's multi_logloss:1.56022
# [3]:	test's multi_logloss:1.53961
# [4]:	test's multi_logloss:1.52511
# [5]:	test's multi_logloss:1.5101
# [6]:	test's multi_logloss:1.4906
# [7]:	test's multi_logloss:1.4716
# [8]:	test's multi_logloss:1.45732
# [9]:	test's multi_logloss:1.43541
# [10]:	test's multi_logloss:1.42368
# [1]:	test's multi_logloss:1.5767
# [2]:	test's multi_logloss:1.54693
# [3]:	test's multi_logloss:1.53219
# [4]:	test's multi_logloss:1.50325
# [5]:	test's multi_logloss:1.48257
# [6]:	test's multi_logloss:1.46582
# [7]:	test's multi_logloss:1.4337
# [8]:	test's multi_logloss:1.42288
# [9]:	test's multi_logloss:1.40562
# [10]:	test's multi_logloss:1.39003
# [1]:	test's multi_logloss:1.5736
# [2]:	test's multi_logloss:1.54089
# [3]:	test's multi_logloss:1.52252
# [4]:	test's multi_logloss:1.49041
# [5]:	test's multi_logloss:1.46107
# [6]:	test's multi_logloss:1.43556
# [7]:	test's multi_logloss:1.41405
# [8]:	test's multi_logloss:1.40248
# [9]:	test's multi_logloss:1.37969
# [10]:	test's multi_logloss:1.36048
# [1]:	test's multi_logloss:1.5712
# [2]:	test's multi_logloss:1.5348
# [3]:	test's multi_logloss:1.51355
# [4]:	test's multi_logloss:1.4823
# [5]:	test's multi_logloss:1.4501
# [6]:	test's multi_logloss:1.42774
# [7]:	test's multi_logloss:1.40428
# [8]:	test's multi_logloss:1.38713
# [9]:	test's multi_logloss:1.36839
# [10]:	test's multi_logloss:1.36082
# [1]:	test's multi_logloss:1.56948
# [2]:	test's multi_logloss:1.52808
# [3]:	test's multi_logloss:1.50226
# [4]:	test's multi_logloss:1.46735
# [5]:	test's multi_logloss:1.43228
# [6]:	test's multi_logloss:1.40659
# [7]:	test's multi_logloss:1.38529
# [8]:	test's multi_logloss:1.36862
# [9]:	test's multi_logloss:1.35136
# [10]:	test's multi_logloss:1.3396
# [1]:	test's multi_logloss:1.56846
# [2]:	test's multi_logloss:1.52477
# [3]:	test's multi_logloss:1.49983
# [4]:	test's multi_logloss:1.47143
# [5]:	test's multi_logloss:1.44091
# [6]:	test's multi_logloss:1.41318
# [7]:	test's multi_logloss:1.38037
# [8]:	test's multi_logloss:1.36602
# [9]:	test's multi_logloss:1.3586
# [10]:	test's multi_logloss:1.34582
# [1]:	test's multi_logloss:1.59942
# [2]:	test's multi_logloss:1.59209
# [3]:	test's multi_logloss:1.58607
# [4]:	test's multi_logloss:1.57753
# [5]:	test's multi_logloss:1.56983
# [6]:	test's multi_logloss:1.5652
# [7]:	test's multi_logloss:1.55898
# [8]:	test's multi_logloss:1.55089
# [9]:	test's multi_logloss:1.54428
# [10]:	test's multi_logloss:1.53644
# [1]:	test's multi_logloss:1.59026
# [2]:	test's multi_logloss:1.57879
# [3]:	test's multi_logloss:1.56756
# [4]:	test's multi_logloss:1.55205
# [5]:	test's multi_logloss:1.54036
# [6]:	test's multi_logloss:1.52543
# [7]:	test's multi_logloss:1.51946
# [8]:	test's multi_logloss:1.50779
# [9]:	test's multi_logloss:1.49525
# [10]:	test's multi_logloss:1.48614
# [1]:	test's multi_logloss:1.58199
# [2]:	test's multi_logloss:1.56578
# [3]:	test's multi_logloss:1.54265
# [4]:	test's multi_logloss:1.52605
# [5]:	test's multi_logloss:1.50768
# [6]:	test's multi_logloss:1.49036
# [7]:	test's multi_logloss:1.47823
# [8]:	test's multi_logloss:1.46246
# [9]:	test's multi_logloss:1.44482
# [10]:	test's multi_logloss:1.43043
# [1]:	test's multi_logloss:1.57462
# [2]:	test's multi_logloss:1.55003
# [3]:	test's multi_logloss:1.52012
# [4]:	test's multi_logloss:1.5045
# [5]:	test's multi_logloss:1.48652
# [6]:	test's multi_logloss:1.46766
# [7]:	test's multi_logloss:1.44007
# [8]:	test's multi_logloss:1.42036
# [9]:	test's multi_logloss:1.40496
# [10]:	test's multi_logloss:1.38692
# [1]:	test's multi_logloss:1.56815
# [2]:	test's multi_logloss:1.5407
# [3]:	test's multi_logloss:1.50916
# [4]:	test's multi_logloss:1.48682
# [5]:	test's multi_logloss:1.45373
# [6]:	test's multi_logloss:1.43155
# [7]:	test's multi_logloss:1.41602
# [8]:	test's multi_logloss:1.39566
# [9]:	test's multi_logloss:1.38346
# [10]:	test's multi_logloss:1.3669
# [1]:	test's multi_logloss:1.56259
# [2]:	test's multi_logloss:1.52815
# [3]:	test's multi_logloss:1.49877
# [4]:	test's multi_logloss:1.46894
# [5]:	test's multi_logloss:1.43882
# [6]:	test's multi_logloss:1.41676
# [7]:	test's multi_logloss:1.39071
# [8]:	test's multi_logloss:1.37211
# [9]:	test's multi_logloss:1.36562
# [10]:	test's multi_logloss:1.3522
# [1]:	test's multi_logloss:1.55796
# [2]:	test's multi_logloss:1.52757
# [3]:	test's multi_logloss:1.48345
# [4]:	test's multi_logloss:1.44748
# [5]:	test's multi_logloss:1.42898
# [6]:	test's multi_logloss:1.40258
# [7]:	test's multi_logloss:1.38934
# [8]:	test's multi_logloss:1.36891
# [9]:	test's multi_logloss:1.36273
# [10]:	test's multi_logloss:1.35445
# [1]:	test's multi_logloss:1.55425
# [2]:	test's multi_logloss:1.52748
# [3]:	test's multi_logloss:1.49138
# [4]:	test's multi_logloss:1.4561
# [5]:	test's multi_logloss:1.44444
# [6]:	test's multi_logloss:1.4184
# [7]:	test's multi_logloss:1.40493
# [8]:	test's multi_logloss:1.38257
# [9]:	test's multi_logloss:1.35825
# [10]:	test's multi_logloss:1.34276
# [1]:	test's multi_logloss:1.55147
# [2]:	test's multi_logloss:1.523
# [3]:	test's multi_logloss:1.48809
# [4]:	test's multi_logloss:1.45284
# [5]:	test's multi_logloss:1.4109
# [6]:	test's multi_logloss:1.37528
# [7]:	test's multi_logloss:1.35818
# [8]:	test's multi_logloss:1.35097
# [9]:	test's multi_logloss:1.33812
# [10]:	test's multi_logloss:1.32687
# [1]:	test's multi_logloss:1.54962
# [2]:	test's multi_logloss:1.51781
# [3]:	test's multi_logloss:1.4858
# [4]:	test's multi_logloss:1.43116
# [5]:	test's multi_logloss:1.40574
# [6]:	test's multi_logloss:1.3928
# [7]:	test's multi_logloss:1.37045
# [8]:	test's multi_logloss:1.35625
# [9]:	test's multi_logloss:1.3447
# [10]:	test's multi_logloss:1.30852
# [1]:	test's multi_logloss:1.59794
# [2]:	test's multi_logloss:1.58989
# [3]:	test's multi_logloss:1.58303
# [4]:	test's multi_logloss:1.57446
# [5]:	test's multi_logloss:1.5658
# [6]:	test's multi_logloss:1.5543
# [7]:	test's multi_logloss:1.54455
# [8]:	test's multi_logloss:1.53539
# [9]:	test's multi_logloss:1.52889
# [10]:	test's multi_logloss:1.52284
# [1]:	test's multi_logloss:1.58756
# [2]:	test's multi_logloss:1.57394
# [3]:	test's multi_logloss:1.55619
# [4]:	test's multi_logloss:1.53337
# [5]:	test's multi_logloss:1.52051
# [6]:	test's multi_logloss:1.509
# [7]:	test's multi_logloss:1.49544
# [8]:	test's multi_logloss:1.48734
# [9]:	test's multi_logloss:1.4746
# [10]:	test's multi_logloss:1.46346
# [1]:	test's multi_logloss:1.57831
# [2]:	test's multi_logloss:1.55912
# [3]:	test's multi_logloss:1.52828
# [4]:	test's multi_logloss:1.50847
# [5]:	test's multi_logloss:1.49457
# [6]:	test's multi_logloss:1.47855
# [7]:	test's multi_logloss:1.46208
# [8]:	test's multi_logloss:1.44389
# [9]:	test's multi_logloss:1.43156
# [10]:	test's multi_logloss:1.42047
# [1]:	test's multi_logloss:1.57023
# [2]:	test's multi_logloss:1.5457
# [3]:	test's multi_logloss:1.51442
# [4]:	test's multi_logloss:1.48838
# [5]:	test's multi_logloss:1.46652
# [6]:	test's multi_logloss:1.45115
# [7]:	test's multi_logloss:1.42594
# [8]:	test's multi_logloss:1.4152
# [9]:	test's multi_logloss:1.40532
# [10]:	test's multi_logloss:1.39355
# [1]:	test's multi_logloss:1.56334
# [2]:	test's multi_logloss:1.53793
# [3]:	test's multi_logloss:1.51501
# [4]:	test's multi_logloss:1.48194
# [5]:	test's multi_logloss:1.45329
# [6]:	test's multi_logloss:1.43056
# [7]:	test's multi_logloss:1.41723
# [8]:	test's multi_logloss:1.40511
# [9]:	test's multi_logloss:1.39328
# [10]:	test's multi_logloss:1.38776
# [1]:	test's multi_logloss:1.55765
# [2]:	test's multi_logloss:1.53286
# [3]:	test's multi_logloss:1.49878
# [4]:	test's multi_logloss:1.4579
# [5]:	test's multi_logloss:1.44093
# [6]:	test's multi_logloss:1.42934
# [7]:	test's multi_logloss:1.40799
# [8]:	test's multi_logloss:1.39314
# [9]:	test's multi_logloss:1.37314
# [10]:	test's multi_logloss:1.36324
# [1]:	test's multi_logloss:1.55318
# [2]:	test's multi_logloss:1.53707
# [3]:	test's multi_logloss:1.50329
# [4]:	test's multi_logloss:1.48517
# [5]:	test's multi_logloss:1.45544
# [6]:	test's multi_logloss:1.42444
# [7]:	test's multi_logloss:1.40691
# [8]:	test's multi_logloss:1.39525
# [9]:	test's multi_logloss:1.37663
# [10]:	test's multi_logloss:1.34955
# [1]:	test's multi_logloss:1.54994
# [2]:	test's multi_logloss:1.53232
# [3]:	test's multi_logloss:1.49497
# [4]:	test's multi_logloss:1.45857
# [5]:	test's multi_logloss:1.42834
# [6]:	test's multi_logloss:1.39906
# [7]:	test's multi_logloss:1.36527
# [8]:	test's multi_logloss:1.35733
# [9]:	test's multi_logloss:1.33597
# [10]:	test's multi_logloss:1.33799
# [1]:	test's multi_logloss:1.54792
# [2]:	test's multi_logloss:1.52355
# [3]:	test's multi_logloss:1.48215
# [4]:	test's multi_logloss:1.43858
# [5]:	test's multi_logloss:1.40381
# [6]:	test's multi_logloss:1.39235
# [7]:	test's multi_logloss:1.38579
# [8]:	test's multi_logloss:1.36778
# [9]:	test's multi_logloss:1.35025
# [10]:	test's multi_logloss:1.33817
# [1]:	test's multi_logloss:1.54712
# [2]:	test's multi_logloss:1.52797
# [3]:	test's multi_logloss:1.4829
# [4]:	test's multi_logloss:1.42509
# [5]:	test's multi_logloss:1.39802
# [6]:	test's multi_logloss:1.38226
# [7]:	test's multi_logloss:1.35472
# [8]:	test's multi_logloss:1.35161
# [9]:	test's multi_logloss:1.34227
# [10]:	test's multi_logloss:1.32976
# [1]:	test's multi_logloss:1.59725
# [2]:	test's multi_logloss:1.58658
# [3]:	test's multi_logloss:1.57535
# [4]:	test's multi_logloss:1.56444
# [5]:	test's multi_logloss:1.55498
# [6]:	test's multi_logloss:1.54607
# [7]:	test's multi_logloss:1.53929
# [8]:	test's multi_logloss:1.53337
# [9]:	test's multi_logloss:1.52577
# [10]:	test's multi_logloss:1.5181
# [1]:	test's multi_logloss:1.58641
# [2]:	test's multi_logloss:1.56494
# [3]:	test's multi_logloss:1.54446
# [4]:	test's multi_logloss:1.52541
# [5]:	test's multi_logloss:1.51182
# [6]:	test's multi_logloss:1.49955
# [7]:	test's multi_logloss:1.4865
# [8]:	test's multi_logloss:1.47011
# [9]:	test's multi_logloss:1.45679
# [10]:	test's multi_logloss:1.44439
# [1]:	test's multi_logloss:1.57694
# [2]:	test's multi_logloss:1.55199
# [3]:	test's multi_logloss:1.53042
# [4]:	test's multi_logloss:1.5118
# [5]:	test's multi_logloss:1.48589
# [6]:	test's multi_logloss:1.46605
# [7]:	test's multi_logloss:1.44993
# [8]:	test's multi_logloss:1.43534
# [9]:	test's multi_logloss:1.4209
# [10]:	test's multi_logloss:1.41019
# [1]:	test's multi_logloss:1.5689
# [2]:	test's multi_logloss:1.54442
# [3]:	test's multi_logloss:1.49473
# [4]:	test's multi_logloss:1.47003
# [5]:	test's multi_logloss:1.44939
# [6]:	test's multi_logloss:1.43176
# [7]:	test's multi_logloss:1.40984
# [8]:	test's multi_logloss:1.39429
# [9]:	test's multi_logloss:1.38057
# [10]:	test's multi_logloss:1.3681
# [1]:	test's multi_logloss:1.56231
# [2]:	test's multi_logloss:1.5419
# [3]:	test's multi_logloss:1.51094
# [4]:	test's multi_logloss:1.47788
# [5]:	test's multi_logloss:1.4429
# [6]:	test's multi_logloss:1.42146
# [7]:	test's multi_logloss:1.40212
# [8]:	test's multi_logloss:1.38652
# [9]:	test's multi_logloss:1.36542
# [10]:	test's multi_logloss:1.3503
# [1]:	test's multi_logloss:1.55722
# [2]:	test's multi_logloss:1.52845
# [3]:	test's multi_logloss:1.49555
# [4]:	test's multi_logloss:1.45899
# [5]:	test's multi_logloss:1.44085
# [6]:	test's multi_logloss:1.41425
# [7]:	test's multi_logloss:1.39007
# [8]:	test's multi_logloss:1.38658
# [9]:	test's multi_logloss:1.36567
# [10]:	test's multi_logloss:1.35417
# [1]:	test's multi_logloss:1.55364
# [2]:	test's multi_logloss:1.52711
# [3]:	test's multi_logloss:1.4767
# [4]:	test's multi_logloss:1.44737
# [5]:	test's multi_logloss:1.4176
# [6]:	test's multi_logloss:1.39495
# [7]:	test's multi_logloss:1.3803
# [8]:	test's multi_logloss:1.36925
# [9]:	test's multi_logloss:1.35942
# [10]:	test's multi_logloss:1.3443
# [1]:	test's multi_logloss:1.55158
# [2]:	test's multi_logloss:1.53083
# [3]:	test's multi_logloss:1.49171
# [4]:	test's multi_logloss:1.46809
# [5]:	test's multi_logloss:1.43987
# [6]:	test's multi_logloss:1.41667
# [7]:	test's multi_logloss:1.40129
# [8]:	test's multi_logloss:1.38746
# [9]:	test's multi_logloss:1.36247
# [10]:	test's multi_logloss:1.35386
# [1]:	test's multi_logloss:1.55105
# [2]:	test's multi_logloss:1.52203
# [3]:	test's multi_logloss:1.50156
# [4]:	test's multi_logloss:1.46492
# [5]:	test's multi_logloss:1.42839
# [6]:	test's multi_logloss:1.40652
# [7]:	test's multi_logloss:1.39685
# [8]:	test's multi_logloss:1.38729
# [9]:	test's multi_logloss:1.3673
# [10]:	test's multi_logloss:1.35937
# [1]:	test's multi_logloss:1.55203
# [2]:	test's multi_logloss:1.53218
# [3]:	test's multi_logloss:1.46946
# [4]:	test's multi_logloss:1.43934
# [5]:	test's multi_logloss:1.40633
# [6]:	test's multi_logloss:1.38379
# [7]:	test's multi_logloss:1.3809
# [8]:	test's multi_logloss:1.3653
# [9]:	test's multi_logloss:1.35937
# [10]:	test's multi_logloss:1.34393
# [1]:	test's multi_logloss:1.59553
# [2]:	test's multi_logloss:1.58489
# [3]:	test's multi_logloss:1.5747
# [4]:	test's multi_logloss:1.5638
# [5]:	test's multi_logloss:1.55588
# [6]:	test's multi_logloss:1.54445
# [7]:	test's multi_logloss:1.53668
# [8]:	test's multi_logloss:1.52864
# [9]:	test's multi_logloss:1.52065
# [10]:	test's multi_logloss:1.51417
# [1]:	test's multi_logloss:1.58313
# [2]:	test's multi_logloss:1.56422
# [3]:	test's multi_logloss:1.55174
# [4]:	test's multi_logloss:1.53432
# [5]:	test's multi_logloss:1.51823
# [6]:	test's multi_logloss:1.5018
# [7]:	test's multi_logloss:1.48853
# [8]:	test's multi_logloss:1.47695
# [9]:	test's multi_logloss:1.46265
# [10]:	test's multi_logloss:1.44993
# [1]:	test's multi_logloss:1.57232
# [2]:	test's multi_logloss:1.54404
# [3]:	test's multi_logloss:1.51502
# [4]:	test's multi_logloss:1.50486
# [5]:	test's multi_logloss:1.48496
# [6]:	test's multi_logloss:1.46626
# [7]:	test's multi_logloss:1.44639
# [8]:	test's multi_logloss:1.42893
# [9]:	test's multi_logloss:1.41189
# [10]:	test's multi_logloss:1.39527
# [1]:	test's multi_logloss:1.56315
# [2]:	test's multi_logloss:1.5393
# [3]:	test's multi_logloss:1.50162
# [4]:	test's multi_logloss:1.47118
# [5]:	test's multi_logloss:1.45012
# [6]:	test's multi_logloss:1.43781
# [7]:	test's multi_logloss:1.41714
# [8]:	test's multi_logloss:1.40009
# [9]:	test's multi_logloss:1.39018
# [10]:	test's multi_logloss:1.37316
# [1]:	test's multi_logloss:1.55567
# [2]:	test's multi_logloss:1.53372
# [3]:	test's multi_logloss:1.49418
# [4]:	test's multi_logloss:1.45547
# [5]:	test's multi_logloss:1.43465
# [6]:	test's multi_logloss:1.41242
# [7]:	test's multi_logloss:1.39542
# [8]:	test's multi_logloss:1.37874
# [9]:	test's multi_logloss:1.35446
# [10]:	test's multi_logloss:1.34112
# [1]:	test's multi_logloss:1.54991
# [2]:	test's multi_logloss:1.52379
# [3]:	test's multi_logloss:1.48684
# [4]:	test's multi_logloss:1.4582
# [5]:	test's multi_logloss:1.43609
# [6]:	test's multi_logloss:1.40206
# [7]:	test's multi_logloss:1.3854
# [8]:	test's multi_logloss:1.35547
# [9]:	test's multi_logloss:1.3379
# [10]:	test's multi_logloss:1.31889
# [1]:	test's multi_logloss:1.54591
# [2]:	test's multi_logloss:1.5076
# [3]:	test's multi_logloss:1.4714
# [4]:	test's multi_logloss:1.42487
# [5]:	test's multi_logloss:1.39043
# [6]:	test's multi_logloss:1.36692
# [7]:	test's multi_logloss:1.3622
# [8]:	test's multi_logloss:1.345
# [9]:	test's multi_logloss:1.32142
# [10]:	test's multi_logloss:1.31571
# [1]:	test's multi_logloss:1.54367
# [2]:	test's multi_logloss:1.51199
# [3]:	test's multi_logloss:1.47059
# [4]:	test's multi_logloss:1.44994
# [5]:	test's multi_logloss:1.41883
# [6]:	test's multi_logloss:1.39239
# [7]:	test's multi_logloss:1.37875
# [8]:	test's multi_logloss:1.36422
# [9]:	test's multi_logloss:1.34959
# [10]:	test's multi_logloss:1.34618
# [1]:	test's multi_logloss:1.54319
# [2]:	test's multi_logloss:1.51926
# [3]:	test's multi_logloss:1.47047
# [4]:	test's multi_logloss:1.44883
# [5]:	test's multi_logloss:1.42179
# [6]:	test's multi_logloss:1.40736
# [7]:	test's multi_logloss:1.39178
# [8]:	test's multi_logloss:1.38046
# [9]:	test's multi_logloss:1.37878
# [10]:	test's multi_logloss:1.37191
# [1]:	test's multi_logloss:1.54445
# [2]:	test's multi_logloss:1.52917
# [3]:	test's multi_logloss:1.48521
# [4]:	test's multi_logloss:1.47431
# [5]:	test's multi_logloss:1.45345
# [6]:	test's multi_logloss:1.42988
# [7]:	test's multi_logloss:1.42508
# [8]:	test's multi_logloss:1.41613
# [9]:	test's multi_logloss:1.39597
# [10]:	test's multi_logloss:1.39303
# [1]:	test's multi_logloss:1.59474
# [2]:	test's multi_logloss:1.58188
# [3]:	test's multi_logloss:1.56879
# [4]:	test's multi_logloss:1.55882
# [5]:	test's multi_logloss:1.55133
# [6]:	test's multi_logloss:1.53928
# [7]:	test's multi_logloss:1.52949
# [8]:	test's multi_logloss:1.52152
# [9]:	test's multi_logloss:1.50905
# [10]:	test's multi_logloss:1.49922
# [1]:	test's multi_logloss:1.58175
# [2]:	test's multi_logloss:1.56132
# [3]:	test's multi_logloss:1.54914
# [4]:	test's multi_logloss:1.53525
# [5]:	test's multi_logloss:1.52583
# [6]:	test's multi_logloss:1.50369
# [7]:	test's multi_logloss:1.48855
# [8]:	test's multi_logloss:1.47133
# [9]:	test's multi_logloss:1.46047
# [10]:	test's multi_logloss:1.44492
# [1]:	test's multi_logloss:1.57056
# [2]:	test's multi_logloss:1.5462
# [3]:	test's multi_logloss:1.51962
# [4]:	test's multi_logloss:1.49783
# [5]:	test's multi_logloss:1.47753
# [6]:	test's multi_logloss:1.45977
# [7]:	test's multi_logloss:1.43761
# [8]:	test's multi_logloss:1.41267
# [9]:	test's multi_logloss:1.3943
# [10]:	test's multi_logloss:1.38226
# [1]:	test's multi_logloss:1.56123
# [2]:	test's multi_logloss:1.53544
# [3]:	test's multi_logloss:1.49844
# [4]:	test's multi_logloss:1.47319
# [5]:	test's multi_logloss:1.45461
# [6]:	test's multi_logloss:1.43742
# [7]:	test's multi_logloss:1.41608
# [8]:	test's multi_logloss:1.40039
# [9]:	test's multi_logloss:1.38485
# [10]:	test's multi_logloss:1.36847
# [1]:	test's multi_logloss:1.55383
# [2]:	test's multi_logloss:1.5229
# [3]:	test's multi_logloss:1.49859
# [4]:	test's multi_logloss:1.46533
# [5]:	test's multi_logloss:1.44421
# [6]:	test's multi_logloss:1.42615
# [7]:	test's multi_logloss:1.397
# [8]:	test's multi_logloss:1.37826
# [9]:	test's multi_logloss:1.36354
# [10]:	test's multi_logloss:1.35308
# [1]:	test's multi_logloss:1.5484
# [2]:	test's multi_logloss:1.51999
# [3]:	test's multi_logloss:1.47823
# [4]:	test's multi_logloss:1.45697
# [5]:	test's multi_logloss:1.43003
# [6]:	test's multi_logloss:1.42205
# [7]:	test's multi_logloss:1.39717
# [8]:	test's multi_logloss:1.38134
# [9]:	test's multi_logloss:1.36265
# [10]:	test's multi_logloss:1.34567
# [1]:	test's multi_logloss:1.54497
# [2]:	test's multi_logloss:1.51656
# [3]:	test's multi_logloss:1.47444
# [4]:	test's multi_logloss:1.44139
# [5]:	test's multi_logloss:1.41957
# [6]:	test's multi_logloss:1.41578
# [7]:	test's multi_logloss:1.39135
# [8]:	test's multi_logloss:1.37118
# [9]:	test's multi_logloss:1.36625
# [10]:	test's multi_logloss:1.3528
# [1]:	test's multi_logloss:1.54356
# [2]:	test's multi_logloss:1.52422
# [3]:	test's multi_logloss:1.4748
# [4]:	test's multi_logloss:1.45002
# [5]:	test's multi_logloss:1.41616
# [6]:	test's multi_logloss:1.3888
# [7]:	test's multi_logloss:1.39019
# [8]:	test's multi_logloss:1.35795
# [9]:	test's multi_logloss:1.34862
# [10]:	test's multi_logloss:1.3437
# [1]:	test's multi_logloss:1.54416
# [2]:	test's multi_logloss:1.5252
# [3]:	test's multi_logloss:1.48486
# [4]:	test's multi_logloss:1.44776
# [5]:	test's multi_logloss:1.42931
# [6]:	test's multi_logloss:1.40743
# [7]:	test's multi_logloss:1.40872
# [8]:	test's multi_logloss:1.4015
# [9]:	test's multi_logloss:1.38105
# [10]:	test's multi_logloss:1.36836
# [1]:	test's multi_logloss:1.54675
# [2]:	test's multi_logloss:1.52979
# [3]:	test's multi_logloss:1.51738
# [4]:	test's multi_logloss:1.48358
# [5]:	test's multi_logloss:1.45593
# [6]:	test's multi_logloss:1.45282
# [7]:	test's multi_logloss:1.42703
# [8]:	test's multi_logloss:1.41348
# [9]:	test's multi_logloss:1.39089
# [10]:	test's multi_logloss:1.3797
# [1]:	test's multi_logloss:1.59314
# [2]:	test's multi_logloss:1.57914
# [3]:	test's multi_logloss:1.56802
# [4]:	test's multi_logloss:1.55488
# [5]:	test's multi_logloss:1.54159
# [6]:	test's multi_logloss:1.53061
# [7]:	test's multi_logloss:1.5245
# [8]:	test's multi_logloss:1.51325
# [9]:	test's multi_logloss:1.50598
# [10]:	test's multi_logloss:1.49948
# [1]:	test's multi_logloss:1.57872
# [2]:	test's multi_logloss:1.55296
# [3]:	test's multi_logloss:1.53634
# [4]:	test's multi_logloss:1.51962
# [5]:	test's multi_logloss:1.5043
# [6]:	test's multi_logloss:1.48486
# [7]:	test's multi_logloss:1.47111
# [8]:	test's multi_logloss:1.45493
# [9]:	test's multi_logloss:1.44003
# [10]:	test's multi_logloss:1.42804
# [1]:	test's multi_logloss:1.56627
# [2]:	test's multi_logloss:1.53945
# [3]:	test's multi_logloss:1.50859
# [4]:	test's multi_logloss:1.48486
# [5]:	test's multi_logloss:1.46375
# [6]:	test's multi_logloss:1.44133
# [7]:	test's multi_logloss:1.42689
# [8]:	test's multi_logloss:1.4102
# [9]:	test's multi_logloss:1.3958
# [10]:	test's multi_logloss:1.37926
# [1]:	test's multi_logloss:1.55587
# [2]:	test's multi_logloss:1.51954
# [3]:	test's multi_logloss:1.48702
# [4]:	test's multi_logloss:1.45729
# [5]:	test's multi_logloss:1.42765
# [6]:	test's multi_logloss:1.40854
# [7]:	test's multi_logloss:1.39072
# [8]:	test's multi_logloss:1.37271
# [9]:	test's multi_logloss:1.3525
# [10]:	test's multi_logloss:1.3395
# [1]:	test's multi_logloss:1.5476
# [2]:	test's multi_logloss:1.50708
# [3]:	test's multi_logloss:1.46556
# [4]:	test's multi_logloss:1.44277
# [5]:	test's multi_logloss:1.42318
# [6]:	test's multi_logloss:1.41222
# [7]:	test's multi_logloss:1.39527
# [8]:	test's multi_logloss:1.37536
# [9]:	test's multi_logloss:1.36608
# [10]:	test's multi_logloss:1.34166
# [1]:	test's multi_logloss:1.54151
# [2]:	test's multi_logloss:1.50552
# [3]:	test's multi_logloss:1.46236
# [4]:	test's multi_logloss:1.43494
# [5]:	test's multi_logloss:1.41648
# [6]:	test's multi_logloss:1.39576
# [7]:	test's multi_logloss:1.36555
# [8]:	test's multi_logloss:1.33046
# [9]:	test's multi_logloss:1.33341
# [10]:	test's multi_logloss:1.31984
# [1]:	test's multi_logloss:1.53763
# [2]:	test's multi_logloss:1.50173
# [3]:	test's multi_logloss:1.44249
# [4]:	test's multi_logloss:1.41575
# [5]:	test's multi_logloss:1.39791
# [6]:	test's multi_logloss:1.38046
# [7]:	test's multi_logloss:1.36015
# [8]:	test's multi_logloss:1.34489
# [9]:	test's multi_logloss:1.32296
# [10]:	test's multi_logloss:1.30208
# [1]:	test's multi_logloss:1.53597
# [2]:	test's multi_logloss:1.5335
# [3]:	test's multi_logloss:1.49024
# [4]:	test's multi_logloss:1.46814
# [5]:	test's multi_logloss:1.46147
# [6]:	test's multi_logloss:1.43863
# [7]:	test's multi_logloss:1.4214
# [8]:	test's multi_logloss:1.40308
# [9]:	test's multi_logloss:1.38775
# [10]:	test's multi_logloss:1.37683
# [1]:	test's multi_logloss:1.53653
# [2]:	test's multi_logloss:1.53833
# [3]:	test's multi_logloss:1.49967
# [4]:	test's multi_logloss:1.47007
# [5]:	test's multi_logloss:1.45356
# [6]:	test's multi_logloss:1.45339
# [7]:	test's multi_logloss:1.43968
# [8]:	test's multi_logloss:1.42174
# [9]:	test's multi_logloss:1.41142
# [10]:	test's multi_logloss:1.40835
# [1]:	test's multi_logloss:1.53928
# [2]:	test's multi_logloss:1.51668
# [3]:	test's multi_logloss:1.48771
# [4]:	test's multi_logloss:1.45606
# [5]:	test's multi_logloss:1.44829
# [6]:	test's multi_logloss:1.45668
# [7]:	test's multi_logloss:1.43027
# [8]:	test's multi_logloss:1.40216
# [9]:	test's multi_logloss:1.41131
# [10]:	test's multi_logloss:1.41597
# [1]:	test's multi_logloss:1.59299
# [2]:	test's multi_logloss:1.58067
# [3]:	test's multi_logloss:1.5665
# [4]:	test's multi_logloss:1.55594
# [5]:	test's multi_logloss:1.54518
# [6]:	test's multi_logloss:1.53602
# [7]:	test's multi_logloss:1.52575
# [8]:	test's multi_logloss:1.51558
# [9]:	test's multi_logloss:1.50556
# [10]:	test's multi_logloss:1.49881
# [1]:	test's multi_logloss:1.57857
# [2]:	test's multi_logloss:1.55878
# [3]:	test's multi_logloss:1.5459
# [4]:	test's multi_logloss:1.52506
# [5]:	test's multi_logloss:1.49922
# [6]:	test's multi_logloss:1.48326
# [7]:	test's multi_logloss:1.4726
# [8]:	test's multi_logloss:1.45839
# [9]:	test's multi_logloss:1.44308
# [10]:	test's multi_logloss:1.43322
# [1]:	test's multi_logloss:1.56627
# [2]:	test's multi_logloss:1.53512
# [3]:	test's multi_logloss:1.50756
# [4]:	test's multi_logloss:1.4822
# [5]:	test's multi_logloss:1.46172
# [6]:	test's multi_logloss:1.44126
# [7]:	test's multi_logloss:1.42177
# [8]:	test's multi_logloss:1.4068
# [9]:	test's multi_logloss:1.38797
# [10]:	test's multi_logloss:1.37824
# [1]:	test's multi_logloss:1.5562
# [2]:	test's multi_logloss:1.51678
# [3]:	test's multi_logloss:1.47736
# [4]:	test's multi_logloss:1.44715
# [5]:	test's multi_logloss:1.43241
# [6]:	test's multi_logloss:1.40866
# [7]:	test's multi_logloss:1.38083
# [8]:	test's multi_logloss:1.36108
# [9]:	test's multi_logloss:1.35063
# [10]:	test's multi_logloss:1.33369
# [1]:	test's multi_logloss:1.54843
# [2]:	test's multi_logloss:1.51166
# [3]:	test's multi_logloss:1.46328
# [4]:	test's multi_logloss:1.43896
# [5]:	test's multi_logloss:1.41836
# [6]:	test's multi_logloss:1.40957
# [7]:	test's multi_logloss:1.38478
# [8]:	test's multi_logloss:1.36065
# [9]:	test's multi_logloss:1.34419
# [10]:	test's multi_logloss:1.32872
# [1]:	test's multi_logloss:1.54301
# [2]:	test's multi_logloss:1.51795
# [3]:	test's multi_logloss:1.47058
# [4]:	test's multi_logloss:1.44017
# [5]:	test's multi_logloss:1.41267
# [6]:	test's multi_logloss:1.39702
# [7]:	test's multi_logloss:1.37812
# [8]:	test's multi_logloss:1.37345
# [9]:	test's multi_logloss:1.35665
# [10]:	test's multi_logloss:1.33916
# [1]:	test's multi_logloss:1.53999
# [2]:	test's multi_logloss:1.52023
# [3]:	test's multi_logloss:1.47885
# [4]:	test's multi_logloss:1.42668
# [5]:	test's multi_logloss:1.40126
# [6]:	test's multi_logloss:1.38715
# [7]:	test's multi_logloss:1.36396
# [8]:	test's multi_logloss:1.34894
# [9]:	test's multi_logloss:1.33726
# [10]:	test's multi_logloss:1.33996
# [1]:	test's multi_logloss:1.53939
# [2]:	test's multi_logloss:1.53615
# [3]:	test's multi_logloss:1.5091
# [4]:	test's multi_logloss:1.48848
# [5]:	test's multi_logloss:1.47729
# [6]:	test's multi_logloss:1.44061
# [7]:	test's multi_logloss:1.42422
# [8]:	test's multi_logloss:1.40135
# [9]:	test's multi_logloss:1.39806
# [10]:	test's multi_logloss:1.3797
# [1]:	test's multi_logloss:1.54118
# [2]:	test's multi_logloss:1.51466
# [3]:	test's multi_logloss:1.47826
# [4]:	test's multi_logloss:1.45312
# [5]:	test's multi_logloss:1.43383
# [6]:	test's multi_logloss:1.42147
# [7]:	test's multi_logloss:1.40317
# [8]:	test's multi_logloss:1.37538
# [9]:	test's multi_logloss:1.35945
# [10]:	test's multi_logloss:1.33883
# [1]:	test's multi_logloss:1.54534
# [2]:	test's multi_logloss:1.51358
# [3]:	test's multi_logloss:1.46373
# [4]:	test's multi_logloss:1.43829
# [5]:	test's multi_logloss:1.42851
# [6]:	test's multi_logloss:1.41647
# [7]:	test's multi_logloss:1.41092
# [8]:	test's multi_logloss:1.40754
# [9]:	test's multi_logloss:1.41939
# [10]:	test's multi_logloss:1.41034
# [1]:	test's multi_logloss:1.59258
# [2]:	test's multi_logloss:1.57834
# [3]:	test's multi_logloss:1.56215
# [4]:	test's multi_logloss:1.55286
# [5]:	test's multi_logloss:1.54189
# [6]:	test's multi_logloss:1.53383
# [7]:	test's multi_logloss:1.52246
# [8]:	test's multi_logloss:1.51145
# [9]:	test's multi_logloss:1.50484
# [10]:	test's multi_logloss:1.49616
# [1]:	test's multi_logloss:1.57786
# [2]:	test's multi_logloss:1.5476
# [3]:	test's multi_logloss:1.53068
# [4]:	test's multi_logloss:1.51186
# [5]:	test's multi_logloss:1.49265
# [6]:	test's multi_logloss:1.47692
# [7]:	test's multi_logloss:1.45773
# [8]:	test's multi_logloss:1.44145
# [9]:	test's multi_logloss:1.43329
# [10]:	test's multi_logloss:1.41812
# [1]:	test's multi_logloss:1.56539
# [2]:	test's multi_logloss:1.53248
# [3]:	test's multi_logloss:1.50117
# [4]:	test's multi_logloss:1.48466
# [5]:	test's multi_logloss:1.46289
# [6]:	test's multi_logloss:1.45206
# [7]:	test's multi_logloss:1.43719
# [8]:	test's multi_logloss:1.41973
# [9]:	test's multi_logloss:1.4017
# [10]:	test's multi_logloss:1.38757
# [1]:	test's multi_logloss:1.55526
# [2]:	test's multi_logloss:1.51344
# [3]:	test's multi_logloss:1.48029
# [4]:	test's multi_logloss:1.46175
# [5]:	test's multi_logloss:1.44172
# [6]:	test's multi_logloss:1.41949
# [7]:	test's multi_logloss:1.39669
# [8]:	test's multi_logloss:1.3813
# [9]:	test's multi_logloss:1.36266
# [10]:	test's multi_logloss:1.35587
# [1]:	test's multi_logloss:1.54757
# [2]:	test's multi_logloss:1.50769
# [3]:	test's multi_logloss:1.47185
# [4]:	test's multi_logloss:1.4454
# [5]:	test's multi_logloss:1.42172
# [6]:	test's multi_logloss:1.40179
# [7]:	test's multi_logloss:1.37751
# [8]:	test's multi_logloss:1.36523
# [9]:	test's multi_logloss:1.34762
# [10]:	test's multi_logloss:1.33915
# [1]:	test's multi_logloss:1.54236
# [2]:	test's multi_logloss:1.51188
# [3]:	test's multi_logloss:1.48186
# [4]:	test's multi_logloss:1.45943
# [5]:	test's multi_logloss:1.43821
# [6]:	test's multi_logloss:1.42281
# [7]:	test's multi_logloss:1.40101
# [8]:	test's multi_logloss:1.38261
# [9]:	test's multi_logloss:1.37127
# [10]:	test's multi_logloss:1.3557
# [1]:	test's multi_logloss:1.53968
# [2]:	test's multi_logloss:1.5033
# [3]:	test's multi_logloss:1.49441
# [4]:	test's multi_logloss:1.46322
# [5]:	test's multi_logloss:1.4302
# [6]:	test's multi_logloss:1.43973
# [7]:	test's multi_logloss:1.41492
# [8]:	test's multi_logloss:1.40813
# [9]:	test's multi_logloss:1.38391
# [10]:	test's multi_logloss:1.3744
# [1]:	test's multi_logloss:1.53955
# [2]:	test's multi_logloss:1.5115
# [3]:	test's multi_logloss:1.50755
# [4]:	test's multi_logloss:1.49619
# [5]:	test's multi_logloss:1.47731
# [6]:	test's multi_logloss:1.45666
# [7]:	test's multi_logloss:1.4496
# [8]:	test's multi_logloss:1.4475
# [9]:	test's multi_logloss:1.42292
# [10]:	test's multi_logloss:1.41472
# [1]:	test's multi_logloss:1.54194
# [2]:	test's multi_logloss:1.53168
# [3]:	test's multi_logloss:1.48563
# [4]:	test's multi_logloss:1.46194
# [5]:	test's multi_logloss:1.43567
# [6]:	test's multi_logloss:1.43103
# [7]:	test's multi_logloss:1.40186
# [8]:	test's multi_logloss:1.38892
# [9]:	test's multi_logloss:1.40696
# [10]:	test's multi_logloss:1.39039
# [1]:	test's multi_logloss:1.54683
# [2]:	test's multi_logloss:1.52484
# [3]:	test's multi_logloss:1.47061
# [4]:	test's multi_logloss:1.47092
# [5]:	test's multi_logloss:1.44437
# [6]:	test's multi_logloss:1.44055
# [7]:	test's multi_logloss:1.42188
# [8]:	test's multi_logloss:1.43748
# [9]:	test's multi_logloss:1.43518
# [10]:	test's multi_logloss:1.45161

# %% [markdown]
# #### 6.结果表，第XX个模型的损失函数最小

# %%
cat("Model ", which.min(perf), " is lowest loss: ", min(perf), sep = "")
# Out:
# Model 77 is lowest loss: 1.400605

# %% [markdown]
# #### 7.损失函数最小的模型参数如下:

# %%
print(grid_search[which.min(perf), ])
# Out:
#    Learning_rate Num_leaves
# 77           0.7         40

# %% [markdown]
# #### 8.注：
# 1）本人测试以上程序所使用电脑为win10，两核四线程；
# 2）本人所使用的lightgbm为CPU版本，未调用GPU；
# 3) 本人所测试程序为R版本lightgbm，本人所用R为Microsoft R Server9.1.0版本；
# 4）本人运行循环程序时长为50秒(删除model及清理内存致使比网络版多了5秒钟，即每迭代一次，多了0.05秒）；
# 5）栅格设置处，learning_rate/num_leaves的每组值之间的间距设置不合理，例如learning的每个值之间的间距随着learning_rate的增加而增加更为合理，此处设置只是为了说明问题而已，请根据实际情况决定，勿采纳！
